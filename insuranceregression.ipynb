# %%
## correct one
! pip install --upgrade scikit-learn
import pandas as pd
df=pd.read_csv(r"C:\Users\sakth\Downloads\synthetic_insurance_data_no_encoding.csv")
import warnings
warnings.filterwarnings("ignore")

# %%
df
# Out:
#       Age  Annual_Income  Claim_History Risk_Score  Fraud_Label  \
# 0      58         181739              3     Medium            0
# 1      71         209192              5     Medium            0
# 2      48         144961              5        Low            0
# 3      34         101258              4        Low            0
# 4      62         181607              6        Low            0
# ...   ...            ...            ...        ...          ...
# 4995   22          69058              1        Low            0
# 4996   47         145376              5     Medium            0
# 4997   25          81710              1        Low            0
# 4998   63         194882              6        Low            0
# 4999   63         185141              5        Low            0
#
#       Premium_Amount  Claim_Amount Policy_Type  Gender
# 0               9677         19145      Health    Male
# 1              11011         21151    Property  Female
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
X=df[['Age','Annual_Income','Claim_History','Risk_Score','Fraud_Label','Premium_Amount','Policy_Type','Gender']]

# %%
X
# Out:
#       Age  Annual_Income  Claim_History Risk_Score  Fraud_Label  \
# 0      58         181739              3     Medium            0
# 1      71         209192              5     Medium            0
# 2      48         144961              5        Low            0
# 3      34         101258              4        Low            0
# 4      62         181607              6        Low            0
# ...   ...            ...            ...        ...          ...
# 4995   22          69058              1        Low            0
# 4996   47         145376              5     Medium            0
# 4997   25          81710              1        Low            0
# 4998   63         194882              6        Low            0
# 4999   63         185141              5        Low            0
#
#       Premium_Amount Policy_Type  Gender
# 0               9677      Health    Male
# 1              11011    Property  Female
# 2               7914        Life    Male
# ...

# %%
Y=df[['Claim_Amount']]

# %%
Y
# Out:
#       Claim_Amount
# 0            19145
# 1            21151
# 2            14251
# 3            10944
# 4            17613
# ...            ...
# 4995          8874
# 4996         15516
# 4997          9679
# 4998         17706
# 4999         18600
#
# [5000 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()

X['Risk_Score']=le.fit_transform(X['Risk_Score'])

# %%
ohe = OneHotEncoder(sparse_output=False)  
policy_encoded = ohe.fit_transform(X[['Policy_Type']])


policy_df = pd.DataFrame(policy_encoded, columns=ohe.get_feature_names_out(['Policy_Type'])).astype(int)

X = X.drop(columns=['Policy_Type']).reset_index(drop=True)
X = pd.concat([X, policy_df], axis=1)

# %%
X
# Out:
#       Age  Annual_Income  Claim_History  Risk_Score  Fraud_Label  \
# 0      58         181739              3           2            0
# 1      71         209192              5           2            0
# 2      48         144961              5           1            0
# 3      34         101258              4           1            0
# 4      62         181607              6           1            0
# ...   ...            ...            ...         ...          ...
# 4995   22          69058              1           1            0
# 4996   47         145376              5           2            0
# 4997   25          81710              1           1            0
# 4998   63         194882              6           1            0
# 4999   63         185141              5           1            0
#
#       Premium_Amount  Gender  Policy_Type_Health  Policy_Type_Life  \
# 0               9677    Male                   1                 0
# ...

# %%
gender_encoded=ohe.fit_transform(X[['Gender']])
gender_df=pd.DataFrame(gender_encoded,columns=ohe.get_feature_names_out(['Gender'])).astype(int)
X=X.drop(columns=['Gender']).reset_index(drop=True)
X=pd.concat([X,gender_df],axis=1)

# %%
X
# Out:
#       Age  Annual_Income  Claim_History  Risk_Score  Fraud_Label  \
# 0      58         181739              3           2            0
# 1      71         209192              5           2            0
# 2      48         144961              5           1            0
# 3      34         101258              4           1            0
# 4      62         181607              6           1            0
# ...   ...            ...            ...         ...          ...
# 4995   22          69058              1           1            0
# 4996   47         145376              5           2            0
# 4997   25          81710              1           1            0
# 4998   63         194882              6           1            0
# 4999   63         185141              5           1            0
#
#       Premium_Amount  Policy_Type_Health  Policy_Type_Life  \
# 0               9677                   1                 0
# 1              11011                   0                 0
# ...

# %%
Y
# Out:
#       Claim_Amount
# 0            19145
# 1            21151
# 2            14251
# 3            10944
# 4            17613
# ...            ...
# 4995          8874
# 4996         15516
# 4997          9679
# 4998         17706
# 4999         18600
#
# [5000 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
se=MinMaxScaler()
X_scaled=se.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
ypred_train=model.predict(X_train)
ypred_test=model.predict(X_test)
print(r2_score(ypred_test,Y_test))
print(r2_score(ypred_train,Y_train))
# Out:
# 0.9877445788844379
# 0.9981395386330358

# %%
X
# Out:
#       Age  Annual_Income  Claim_History  Risk_Score  Fraud_Label  \
# 0      58         181739              3           2            0
# 1      71         209192              5           2            0
# 2      48         144961              5           1            0
# 3      34         101258              4           1            0
# 4      62         181607              6           1            0
# ...   ...            ...            ...         ...          ...
# 4995   22          69058              1           1            0
# 4996   47         145376              5           2            0
# 4997   25          81710              1           1            0
# 4998   63         194882              6           1            0
# 4999   63         185141              5           1            0
#
#       Premium_Amount  Policy_Type_Health  Policy_Type_Life  \
# 0               9677                   1                 0
# 1              11011                   0                 0
# ...

# %%
import numpy as np
inputdata = (58,	181739,	3,	2	,0	,9677	,1	,0	,0,	0,	1,	0)
inputdataasarray = np.asarray(inputdata)
inputdatareshaped = inputdataasarray.reshape(1,-1)
prediction = model.predict((inputdatareshaped))
print(*prediction)
# Out:
# 24113.76

# %%
import pickle
with open('insuranceregression1.pkl','wb')as file:
    pickle.dump(model,file)
